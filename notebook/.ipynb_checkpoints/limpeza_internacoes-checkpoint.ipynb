# %% [markdown]
# # Análise e Limpeza dos dados relacionados a quantidade de internações pelo SUS por estado

# %% [markdown]
# ## Importações dos pacotes

# %%
import pandas as pd
from matplotlib import ticker
from funcoes_datasus import limpa_dados, plot_grafico_linha 
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import date

# %% [markdown]
# ## Dados

# %%
dados = pd.read_csv("C:/Users/pedro/Documents/projeto_modulo_1_bootcamp2_alura/dados_brutos/A111716189_28_143_208_int.csv", encoding="ISO-8859-1",
                    na_values='-',
                    skiprows = 3, sep=";", skipfooter=12,
                    thousands=".", decimal=",", engine="python")

# %% [markdown]
# fonte : http://tabnet.datasus.gov.br/cgi/deftohtm.exe?sih/cnv/qiuf.def

# %% [markdown]
# Os dados foram coletados do datasus e dizem respeito do número de internações processadas a partir de Janeiro de 2008 por mês e por Unidade Federativa, a fim de causar falsas impressões e ter certeza que os dados são reais e estão atualizados, os dados antes de janeiro de 2008(quando foram processados) serão removidos,o mês de janeiro de 2008 será removido também pois pode haver algum número equivocado.

# %% [markdown]
# Além disso, segundo a própia fonte de dados:'Dados referentes aos últimos seis meses, sujeitos a atualização.', então esses dados desatualizados serão removidos também, e por último a coluna total será removida a fim de melhorar a visualização.

# %% [markdown]
# ## Funções

# %%
@ticker.FuncFormatter
def thousand_formatter(x, pos):
    '''
    Formata os dados para cada Mil internações e mostra duas casas decimais depois da vírgula
    '''
    return "%.2f Mil" % (x/1E3)

# %% [markdown]
# ## Limpeza dos dados

# %%
dados.head()
# Out:
#   Unidade da Federação  2007/Jan  2007/Fev  2007/Mar  2007/Abr  2007/Mai  \
# 0          11 Rondônia       NaN       1.0       NaN       NaN       NaN
# 1              12 Acre       1.0       NaN       NaN       NaN       NaN
# 2          13 Amazonas       3.0       2.0       NaN       1.0       NaN
# 3           14 Roraima       NaN       NaN       NaN       NaN       NaN
# 4              15 Pará       8.0       6.0       NaN       NaN       1.0
#
#    2007/Jun  2007/Jul  2007/Ago  2007/Set  ...  2020/Jul  2020/Ago  2020/Set  \
# 0       NaN       NaN         7        42  ...      8376      8848      8379
# 1       1.0       NaN         5        17  ...      3549      3574      3724
# 2       NaN       1.0        59        69  ...     15417     15709     15727
# 3       1.0       NaN        14         8  ...      3080      3332      3302
# 4       1.0       4.0       404       798  ...     36010     37071     36673
#
# ...

# %%
pd.set_option('display.max_columns',200)
dados.describe()
# Out:
#         2007/Jan   2007/Fev  2007/Mar  2007/Abr  2007/Mai   2007/Jun  \
# count  16.000000  19.000000       4.0       6.0  9.000000  17.000000
# mean    3.812500   3.315789       1.0       1.0  1.888889   2.117647
# std     2.136001   2.944913       0.0       0.0  1.166667   1.363926
# min     1.000000   1.000000       1.0       1.0  1.000000   1.000000
# 25%     2.750000   1.000000       1.0       1.0  1.000000   1.000000
# 50%     3.500000   2.000000       1.0       1.0  1.000000   1.000000
# 75%     5.250000   5.000000       1.0       1.0  3.000000   3.000000
# max     8.000000  12.000000       1.0       1.0  4.000000   5.000000
#
#          2007/Jul    2007/Ago     2007/Set     2007/Out      2007/Nov  \
# count   24.000000   27.000000    27.000000    27.000000     27.000000
# mean    16.000000  234.407407   591.074074  1999.259259   4933.481481
# std     23.123487  221.364520   572.408066  2016.291905   4953.551953
# ...

# %% [markdown]
# Percebe se que os anos anteriores a 2008 tem uma quantidade de linhas menor('count') e parecem tem uma média menor('mean'), provavelmente os dados que correspondem a esses anos na verdade são dados que não foram processados na época quando ocorreram os atendimentos e por esta razão aparece aqui nos dados processados após 2008, além disso os dados de 2020 e 2021 estão bem abaixos também provavavelmente por não estarem atualizados, vamos analisar isso pelo gráfico para ter uma noção melhor.

# %%
#Mudando o estilo de fundo
sns.set_style('darkgrid')
    
#Criando uma palheta de cores
sns.set_palette(sns.color_palette("gist_rainbow", 27))
    
#Criando figura e eixos
fig, ax = plt.subplots(figsize=(16,8)) 

#Criando o gráfico 
dados.drop('Total', axis=1).set_index('Unidade da Federação').T.plot(ax=ax)

 #Plotando as legendas e mudando o tamanho das fontes
plt.title('Internações Pelo SUS Entre Janeiro De 2007 E Março De 2021 Por Estado', fontsize=20)
plt.xlabel('Ano/Mês', fontsize=15)
plt.ylabel('Internações', fontsize=15)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(title='UF', bbox_to_anchor=(1.05, 1), loc='upper left')
ax.yaxis.set_major_formatter(thousand_formatter)
    
#Mostrando o gráfico
plt.show()

# %% [markdown]
# Analisando o gráfico com o número de internações é possível perceber que realmente os dados antes de 2008 e depois de 2020 estão passando uma impressão que pode ser equivocada, parece que os estados não estavam gastando quase nada antes de 2008 e começaram a gastar muito mais e olhando para os dados mais recentes parece que os estados estão começando a gastar menos, o que provavelmente não é verdade.

# %% [markdown]
# Por esta razão estarei limitando esses dados entre fevereiro de 2008(eliminando janeiro por ser o primeiro mês de processamento) e dezembro de 2019(pois os anos após isso parecem sofre uma queda muito brusco o que pode não ser verdade)

# %% [markdown]
# Para isso usarei uma função que está em um arquivo py(funcoes_datasus.py) nesse diretório: https://github.com/Pedro-correa-almeida/Projeto_modulo_1/blob/main/notebook/funcoes_datasus.py

# %%
help(limpa_dados)
# Out:
# Help on function limpa_dados in module funcoes_datasus:
#
# limpa_dados(dados, nome)
#     Função que recebe um conjunto de dados do datasus e faz diversas manipulações:
#
#         renomeia a coluna Unidade da Federação para UF para simplificar
#         cria uma coluna para cada região
#         elimina os números antes do nome dos estados
#         elimina a coluna total
#         transforma as colunas relacionadas a data em uma coluna apenas(coluna data)
#         transforma a coluna data para o tipo date do python
#         restringe a data entre fevereiro de 2008 e dezembro de 2019

# %%
dados=limpa_dados(dados, 'internacoes')
dados
# Out:
#                       UF        regiao       data  internacoes
# 0               Rondônia         Norte 2008-02-01         5562
# 1                   Acre         Norte 2008-02-01         3723
# 2               Amazonas         Norte 2008-02-01        13828
# 3                Roraima         Norte 2008-02-01         1739
# 4                   Pará         Norte 2008-02-01        40225
# ...                  ...           ...        ...          ...
# 3856   Rio Grande do Sul           Sul 2019-12-01        59523
# 3857  Mato Grosso do Sul  Centro-Oeste 2019-12-01        14020
# 3858         Mato Grosso  Centro-Oeste 2019-12-01        14500
# 3859               Goiás  Centro-Oeste 2019-12-01        26978
# 3860    Distrito Federal  Centro-Oeste 2019-12-01        17381
#
# [3861 rows x 4 columns]

# %% [markdown]
# Agora os dados estão formatados no padrão previsto para a análise de correlação no notebook:

# %% [markdown]
# Agora vamos ver como os dados se comportam no gráfico, será utilizada uma função no mesmo arquivo .py:

# %%
help(plot_grafico_linha)
# Out:
# Help on function plot_grafico_linha in module funcoes_datasus:
#
# plot_grafico_linha(dados, y, hue='UF', title=None, ylabel=None, xlabel='Ano/Mês', legend_title=None, formatter=<matplotlib.ticker.StrMethodFormatter object at 0x0000015438C25C88>)
#     Função que recebe o dataframe e plota um gráfico de linha de cada Unidade Federativa com o eixo x com a data e eixo y os valores numéricos

# %%
#Plotando um gráfico para visualizar os dados
plot_grafico_linha(dados, 'internacoes', title='Internações Pelo SUS Entre Fevereiro De 2008 E Dezembro De 2019 Por Estado', legend_title='Estado', formatter=thousand_formatter)

# %% [markdown]
# Observando o gráfico agora está com dados mais coerentes que fazem mais sentido sem bruscas quedas e subidas.

# %% [markdown]
# Vamos analisar agrupando por região para uma análise mais clara.

# %%
dados
# Out:
#                       UF        regiao       data  internacoes
# 0               Rondônia         Norte 2008-02-01         5562
# 1                   Acre         Norte 2008-02-01         3723
# 2               Amazonas         Norte 2008-02-01        13828
# 3                Roraima         Norte 2008-02-01         1739
# 4                   Pará         Norte 2008-02-01        40225
# ...                  ...           ...        ...          ...
# 3856   Rio Grande do Sul           Sul 2019-12-01        59523
# 3857  Mato Grosso do Sul  Centro-Oeste 2019-12-01        14020
# 3858         Mato Grosso  Centro-Oeste 2019-12-01        14500
# 3859               Goiás  Centro-Oeste 2019-12-01        26978
# 3860    Distrito Federal  Centro-Oeste 2019-12-01        17381
#
# [3861 rows x 4 columns]

# %%
#Plotando um gráfico para visualizar os dados
dados_reg = dados.groupby(['regiao', 'data']).sum().reset_index()
plot_grafico_linha(dados_reg, 'internacoes', hue='regiao', title='Internações Pelo SUS Entre Fevereiro De 2008 E Dezembro De 2019 Por Estado', legend_title='Região', formatter=thousand_formatter, ylabel='Internações')

# %% [markdown]
# Percebe se que a quantidade de internações é muito maior nos estados do Sudeste e do Nordeste, imagino que deve ser pela população dos estados nessas regiões, para confirmar isso vou juntar os dados de internações com os dados da população de cada estado, para analisar a quantidade de internações para cada mil habitantes.

# %% [markdown]
# ## Análise em relação a população

# %% [markdown]
# Para analisar esses dados agora em relação a população do estado vou importar os dados em relação a população que foram tratados no notebook:

# %%
dados_pop = pd.read_csv("C:/Users/pedro/Documents/projeto_modulo_1_bootcamp2_alura/dados_limpos/populacao_ano.csv", index_col=0)
dados_pop
# Out:
#                      UF   ano         pop
# 189            Rondônia  2008   1493566.0
# 190                Acre  2008    680073.0
# 191            Amazonas  2008   3341096.0
# 192             Roraima  2008    412783.0
# 193                Pará  2008   7321493.0
# ..                  ...   ...         ...
# 508   Rio Grande do Sul  2019  11377239.0
# 509  Mato Grosso do Sul  2019   2778986.0
# 510         Mato Grosso  2019   3484466.0
# 511               Goiás  2019   7018354.0
# 512    Distrito Federal  2019   3015268.0
#
# [324 rows x 3 columns]

# %% [markdown]
# Criando uma coluna no DataFrame original de ano para juntar com os dados de população

# %%
dados['ano'] = dados['data'].dt.year
dados
# Out:
#                       UF        regiao       data  internacoes   ano
# 0               Rondônia         Norte 2008-02-01         5562  2008
# 1                   Acre         Norte 2008-02-01         3723  2008
# 2               Amazonas         Norte 2008-02-01        13828  2008
# 3                Roraima         Norte 2008-02-01         1739  2008
# 4                   Pará         Norte 2008-02-01        40225  2008
# ...                  ...           ...        ...          ...   ...
# 3856   Rio Grande do Sul           Sul 2019-12-01        59523  2019
# 3857  Mato Grosso do Sul  Centro-Oeste 2019-12-01        14020  2019
# 3858         Mato Grosso  Centro-Oeste 2019-12-01        14500  2019
# 3859               Goiás  Centro-Oeste 2019-12-01        26978  2019
# 3860    Distrito Federal  Centro-Oeste 2019-12-01        17381  2019
#
# [3861 rows x 5 columns]

# %% [markdown]
# Concatenando os dois DataFrames e calculando a quantidade de internações por mil habitantes

# %%
dados = pd.merge(dados, dados_pop, on=['UF','ano'])
dados['internacao_por_mil'] = dados['internacoes'] * 1000/dados['pop']
dados
# Out:
#                     UF        regiao       data  internacoes   ano        pop  \
# 0             Rondônia         Norte 2008-02-01         5562  2008  1493566.0
# 1             Rondônia         Norte 2008-03-01         5105  2008  1493566.0
# 2             Rondônia         Norte 2008-04-01         5175  2008  1493566.0
# 3             Rondônia         Norte 2008-05-01         5148  2008  1493566.0
# 4             Rondônia         Norte 2008-06-01         6099  2008  1493566.0
# ...                ...           ...        ...          ...   ...        ...
# 3856  Distrito Federal  Centro-Oeste 2019-08-01        20342  2019  3015268.0
# 3857  Distrito Federal  Centro-Oeste 2019-09-01        19898  2019  3015268.0
# 3858  Distrito Federal  Centro-Oeste 2019-10-01        20198  2019  3015268.0
# 3859  Distrito Federal  Centro-Oeste 2019-11-01        17807  2019  3015268.0
# 3860  Distrito Federal  Centro-Oeste 2019-12-01        17381  2019  3015268.0
#
#       internacao_por_mil
# ...

# %% [markdown]
# Plotando a média de internação por mil habitantes agrupado por região

# %%
#Plotando um gráfico para visualizar os dados
dados_reg = dados.groupby(['regiao', 'data']).agg({'internacao_por_mil':'mean'}).reset_index()
plot_grafico_linha(dados_reg, 'internacao_por_mil', hue='regiao', title='Internações A Cada Mil Habitantes Pelo SUS \nEntre Fevereiro De 2008 E Dezembro De 2019 Por Estado', legend_title='Região',ylabel='Internações')

# %% [markdown]
# Observando o gráfico de internações em relação à população percebemos que por mais que a região sudeste foi a região que mais teve pessoas internadas, foi a região que apresentou a menor média entre a quantidade de internações à cada mil de cada estado, mostrando que a população precisa ser levada em conta na hora de se analisar dados absoulutos que dependem da quantidade total de habitantes.

# %%
#Salvando os dados limpos no diretório
dados.to_csv("C:/Users/pedro/Documents/projeto_modulo_1_bootcamp2_alura/dados_limpos/internacoes.csv")
